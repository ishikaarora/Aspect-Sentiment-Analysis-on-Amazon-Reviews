# %%
import spacy
import pandas as pd
import os
import sys

# %%
# import os
# import sys
# module_path = os.path.abspath(os.path.join('..'))
# if module_path not in sys.path:
#     sys.path.append(module_path)
    
# from src.models import aspect_extraction

# aspect_extraction.aspect_extraction()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-827c23964a2c> in <module>
#       7 from src.models import aspect_extraction
#       8
# ----> 9 aspect_extraction.aspect_extraction()
#
# ~/Documents/gatech/dva_6242/project/src/models/aspect_extraction.py in aspect_extraction()
#     152     filepath = BASE_PATH + "/data/raw/amazon_reviews_us_Electronics_v1_00.tsv"
#     153
# --> 154     reviews =  fetch_reviews(filepath)
#     155     aspect_list = extract_aspects(reviews)
#     156
#
# ~/Documents/gatech/dva_6242/project/src/models/aspect_extraction.py in fetch_reviews(filepath)
#      19
#      20 def fetch_reviews(filepath):
# ---> 21     raw_data = pd.read_table(filepath,nrows = 300,error_bad_lines=False)
#      22     return raw_data
#      23
#
# ~/miniconda3/envs/dva/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/miniconda3/envs/dva/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/miniconda3/envs/dva/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/miniconda3/envs/dva/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/miniconda3/envs/dva/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'/Users/apple/Documents/gatech/dva_6242/project/notebooks/data/raw/amazon_reviews_us_Electronics_v1_00.tsv' does not exist

# %%
#Get this from some place else. This is just for dummy usage
stop_words=["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", 
            "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", 
            "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", 
            "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", 
            "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", 
            "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", 
            "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", 
            "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", 
            "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than",
            "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]


nlp=spacy.load("en_core_web_lg")

# %%
BASE_PATH = os.path.abspath(os.path.join('..')) # base path of project

file_path = BASE_PATH + '/data/raw/amazon_reviews_us_Electronics_v1_00.tsv'

raw_data = pd.read_table(file_path,error_bad_lines=False, nrows=100)
raw_data
#review_body = raw_data['review_body']
#reviews = raw_data[['review_id', 'review_body']]
# Out:
#    marketplace  customer_id       review_id  product_id  product_parent  \
# 0           US     41409413  R2MTG1GCZLR2DK  B00428R89M       112201306
# 1           US     49668221  R2HBOEM8LE9928  B000068O48       734576678
# 2           US     12338275  R1P4RW1R9FDPEE  B000GGKOG8       614448099
# 3           US     38487968  R1EBPM82ENI67M  B000NU4OTA        72265257
# 4           US     23732619  R372S58V6D11AT  B00JOQIO6S       308169188
# 5           US     21257820  R1A4514XOYI1PD  B008NCD2LG       976385982
# 6           US      3084991  R20D9EHB7N20V6  B00007FGUF       670878953
# 7           US      8153674  R1WUTD8MVSROJU  B00M9V2RMM       508452933
# 8           US     52246189  R1QCYLT25812DM  B00J3O9DYI       766372886
# 9           US     41463864   R904DQPBCEM7A  B00NS1A0E4       458130381
# 10          US      2781942  R1DGA6UQIVLKZ7  B007B5V092       152891509
# 11          US       707292   RLQT3V8SMNIBH  B00IODHGVG       717335277
# 12          US     31463514  R3T9GZS2TMXZGM  B0035PBHX6       249533961
# 13          US     33475055  R24HVAEYP5PLDN  B00K1JJWFO       635791633
# 14          US     16543871  R32KMAPNV5NJPJ  B00S3LJ5EA       659360184
# 15          US     38472651   RC7VLPHUT6UAF  B00B5QNGN6       564421014
# 16          US     26946211  R3G1II8P4KGUAR  B00PLE8QF6       685446417
# 17          US     10195727  R1UBFCBUALL6S5  B00GHUSIU6       595255086
# 18          US     47386264  R1WI5NISM6GAUG  B0045EJY90       892920832
# 19          US     13000908  R27F4OF4BIA4LU  B003BT6BM8       631236454
# 20          US     42944532  R1OD3VMIZCCADZ  B012VIWG28       676077256
# 21          US     13007636   RBNAN5JL5GFYV  B00FZ1AAUE        27240799
# 22          US     49150897  R2DGBZBL7MUX2H  B00F2FHYM0       304108225
# 23          US     51334385  R183T292B7A19F  B00P936188       856423969
# 24          US      5149738  R3ANQJUUCFYRJH  B0045RU68U         1340028
# 25          US     15241735  R1DMFKFFMO6DYB  B00ESM3ZHG       964813452
# 26          US     40862185  R3SQRCBAFSXZW6  B007SP2CO2       595936907
# 27          US      2824337  R320LOSTZ3AE3X  B0111ASH0M       386191037
# 28          US     17848234   R62S4IDIH8O25  B002JR2V7C       104180796
# 29          US     19504814   RZKFO6N2GH92L  B0002QLDLC       960374854
# ..         ...          ...             ...         ...             ...
# 70          US       462252  R39ITSI7RJ8894  B00RSUFT5G       297234572
# 71          US     41720710  R2Q5AMC4M8VH40  B00YNI7G8O       709285816
# 72          US     41146239  R1VQLRTMIBDRDT  B00C7JIBN0       479916274
# 73          US     31364444  R2JEESEFYDVQB2  B00PLCMZ8M       558087999
# 74          US     11891353  R2BX4NP4XPPRUS  B012Z0R34I       936286343
# 75          US      1569092   R7SPUAFZODBZN  B00FPUYSXK        12772685
# 76          US       126728  R2B137PSYXNDGC  B003X1BEKI       197484873
# 77          US      7809544  R146GB865SLP8A  B005F6O0M8        69091996
# 78          US     44692544   RP9RILI2BJIZT  B00NCSIN4W       915797770
# 79          US     48924708   R2OJHJKPRR9AG  B00EWCUK98       779758615
# 80          US     15758524  R2KBH8K2MN7L5T  B00XWKA3FC       418244573
# 81          US     24732189  R1PJS8TX58J3WC  B000IJY8DS       654766735
# 82          US     31350905  R1ORLE4CZA6R5F  B000OG88KY       239721724
# 83          US     15507336  R3QS6L10BUWOOE  B00T2K0ROI        10558218
# 84          US     45905256  R2S8TX3KZU9TNW  B012YZ6ONK       374746816
# 85          US     17942798  R1J0KZCF8TKQR8  B00ND3XGQQ       988240326
# 86          US     51773554  R2GL614E81T6N9  B00CDGSNL2       522761479
# 87          US      3153270  R3CM5K99PSZXJN  B00K7DYACO        98084547
# 88          US     30909410   ROSNGEJRRBNYB  B004E2XB3I       295457644
# 89          US      4791778  R1WH51UHEYIW5Y  B0002MQGR2       271941114
# 90          US     44083852   RRW9IYKB70EPK  B00JGDF31I       847372182
# 91          US     51039431   RVDJ0B8MHUHL4  B0042F3K9W       511813888
# 92          US     20947453  R2666O4LI7I4EZ  B00VMJEK2C       610652919
# 93          US     33162753  R2CQ8PIPIYDDOH  B00E11BO6S       813413850
# 94          US      1321052  R2WYSGXX1RCW6Y  B00RZ9XPX8       544420914
# 95          US     12681886  R2ZGM1SYG0K2OO  B00RFLGJLG       833935017
# 96          US     51453429  R2P1OY2YZ8300R  B00JHKSN5I        48252030
# 97          US      2452291   R3N80JIUYFL60  B00TDNWQN4       299483151
# 98          US     13963852  R3KIAM7QE7Z3ND  B00Q3TFLY2       150402291
# 99          US     18620836  R121DZ7RI29FEL  B000V6R2OK       147674140
#
#                                         product_title product_category  \
# 0   yoomall 5M Antenna WIFI RP-SMA Female to Male ...      Electronics
# 1          Hosa GPM-103 3.5mm TRS to 1/4" TRS Adaptor      Electronics
# 2         Channel Master Titan 2 Antenna Preamplifier      Electronics
# 3   LIMTECH Wall charger + USB Hotsync & Charging ...      Electronics
# 4      Skullcandy Air Raid Portable Bluetooth Speaker      Electronics
# 5   Pioneer SP-BS22-LR Andrew Jones Designed Books...      Electronics
# 6     C2G/Cables to Go 03170 3.5mm F/F Stereo Coupler      Electronics
# 7                           COOLEAD-HDMI Switcher BOX      Electronics
# 8                   Philips Wireless Portable Speaker      Electronics
# 9       PlayStation 3 3D Glasses (Super Value 4 Pack)      Electronics
# 10  JVC HAFR201A Xtreme Xplosive Deep Bass Earbuds...      Electronics
# 11  Sylvania Alarm Clock Radio with CD Player and ...      Electronics
# 12  Coby 8 GB 1.8-Inch Video MP3 Player with FM Radio      Electronics
# 13  Diamond (Original) SRH77CA 144/440 MHz. Dual-B...      Electronics
# 14  Kingvom 8gb 50 Hours Continuous Playback Mp3 P...      Electronics
# 15  JBL Ultra-Portable Speaker with Built-In Bass ...      Electronics
# 16  YIPBOWPT Surface Pro 4 M3 Charger,15V/1.6A 24W...      Electronics
# 17                    StarTech.com Mini USB 2.0 Cable      Electronics
# 18  TEAC CD-P650-B Compact Disc Player with USB an...      Electronics
# 19              Philips SHS8100/28 Earhook Headphones      Electronics
# 20       Brainwavz Hengja - The Headphone Desk Hanger      Electronics
# 21  MOUNT FACTORY Articulating Swivel Full Motion ...      Electronics
# 22  HQRP AC Adapter for Horizon Fitness B600 RC30 ...      Electronics
# 23  Anker 60W 6-Port USB Wall Charger, PowerPort 6...      Electronics
# 24  Seven Star F200 200 Watt 220/240V to 110/120V ...      Electronics
# 25  Cable Matters (2-in-1) Mini-HDMI + Micro-HDMI ...      Electronics
# 26  Monoprice 108323 Premium Hi-Fi DJ Style Over-t...      Electronics
# 27  Battery1inc World's Slimmest and Smallest 15W ...      Electronics
# 28                    Atlantic 74604729 Movie Sleeves      Electronics
# 29         APC RBC35 Replacement Battery Cartridge 35      Electronics
# ..                                                ...              ...
# 70  Bluetooth Earphones, TaoTronics Bluetooth Wire...      Electronics
# 71  HDMI Cable 15 FT - Braided Cord - 4K HDMI 2.0 ...      Electronics
# 72                         ARCTIC P253 BT - Bluetooth      Electronics
# 73  Grace Digital GDI-IRMSamp Microsystem Internet...      Electronics
# 74  Zipbuds SLIDE Sport Earbuds with Mic (Most Dur...      Electronics
# 75     JBL Charge Portable Wireless Bluetooth Speaker      Electronics
# 76                                    Koss Headphones      Electronics
# 77   Mitsubishi WD-65735 180 Watt TV Lamp Replacement      Electronics
# 78                          Skullcandy Hesh Bluetooth      Electronics
# 79  SONOS Compact Wireless Speaker for Streaming M...      Electronics
# 80  Cable Management Sleeve, JOTO Cable Sleeve, [S...      Electronics
# 81  High Speed HDMI Cable Supports Ethernet, 3D an...      Electronics
# 82  Sony SS-B1000 5-1/4-Inch Bookshelf Speakers (P...      Electronics
# 83                                    NO MORE SELLING      Electronics
# 84  Flare Audio R2A Sound Isolating In-Ear Aluminu...      Electronics
# 85  Etekcity RoverBeats T16 Ultra Portable Wireles...      Electronics
# 86                    JAM XT Extreme Wireless Speaker      Electronics
# 87                     Ceptics  Outlet Travel Adapter      Electronics
# 88  Mount-It! TV Wall Mount Full Motion and Heavy-...      Electronics
# 89                                   Optical Splitter      Electronics
# 90  ITIS Replacement Audio Cable Cord For Bose Qui...      Electronics
# 91  Harman Kardon Soundsticks III 2.1 Channel Mult...      Electronics
# 92  ECHOGEAR Full Motion Articulating TV Wall Moun...      Electronics
# 93  Aerb® 4G Waterproof MP3 Music Player for Swimm...      Electronics
# 94                             C&E HDMI to HDMI Cable      Electronics
# 95  1byone OUS00-0562 Amplified HDTV Antenna 50 Mi...      Electronics
# 96  Panasonic eneloop AA New 2100 Cycle Ni-MH Pre-...      Electronics
# 97                        Omaker M4 Portable Speakers      Electronics
# 98  Bluedio N2 Bluetooth V4.1 Wireless Stereo Musi...      Electronics
# 99  Cables Unlimited AUD-1100-25 3.5 mm 25 feet Ma...      Electronics
#
#     star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0             5              0            0    N                 Y
# 1             5              0            0    N                 Y
# 2             5              1            1    N                 Y
# 3             1              0            0    N                 Y
# 4             5              1            1    N                 Y
# 5             5              1            1    N                 Y
# 6             5              0            0    N                 Y
# 7             5              0            0    N                 Y
# 8             4              0            0    N                 Y
# 9             4              0            0    N                 Y
# 10            5              0            0    N                 Y
# 11            5              0            0    N                 Y
# 12            1              0            0    N                 Y
# 13            5              0            1    N                 Y
# 14            5              0            0    N                 Y
# 15            5              0            0    N                 Y
# 16            5              0            0    N                 Y
# 17            5              0            0    N                 Y
# 18            2              4            5    N                 Y
# 19            2              1            1    N                 Y
# 20            5              0            0    N                 N
# 21            4              0            0    N                 Y
# 22            4              0            0    N                 Y
# 23            5              0            0    N                 Y
# 24            5              0            0    N                 Y
# 25            4              1            1    N                 Y
# 26            3              0            0    N                 Y
# 27            5              0            0    N                 Y
# 28            5              0            0    N                 Y
# 29            5              0            0    N                 Y
# ..          ...            ...          ...  ...               ...
# 70            3              0            0    N                 N
# 71            5              0            0    N                 Y
# 72            3              0            0    N                 Y
# 73            5              0            0    N                 Y
# 74            5              3            3    N                 Y
# 75            1              0            0    N                 Y
# 76            5              0            0    N                 Y
# 77            5              0            0    N                 Y
# 78            1              4            6    N                 Y
# 79            5              0            0    N                 Y
# 80            5              1            1    N                 Y
# 81            5              0            0    N                 Y
# 82            4              0            1    N                 Y
# 83            5              7            7    N                 N
# 84            5              2            2    N                 N
# 85            4              0            0    N                 Y
# 86            5              0            0    N                 Y
# 87            5              0            0    N                 Y
# 88            5              0            0    N                 Y
# 89            1              2            2    N                 Y
# 90            1              0            0    N                 Y
# 91            5              1            1    N                 Y
# 92            5              0            0    N                 Y
# 93            1              0            0    N                 Y
# 94            4              0            0    N                 Y
# 95            4              0            0    N                 Y
# 96            5              1            1    N                 Y
# 97            5              0            0    N                 Y
# 98            1              0            0    N                 Y
# 99            4              0            0    N                 Y
#
#                                       review_headline  \
# 0                                          Five Stars
# 1                            It works as advertising.
# 2                                          Five Stars
# 3                                            One Star
# 4                       Overall pleased with the item
# 5                                          Five Stars
# 6                                           Lifesaver
# 7                                          Five Stars
# 8                                          Four Stars
# 9                                          Four Stars
# 10                                         Five Stars
# 11                                         Five Stars
# 12                                           One Star
# 13                                         Five Stars
# 14                                         Five Stars
# 15                                         Five Stars
# 16                                      great product
# 17                                         Five Stars
# 18   It does not copy CD-R s to USB as advertised ...
# 19  Did not last long, Stop working within a year ...
# 20  Simple hanger; clamp is strong, with a pad; ha...
# 21                          Affordable and Functional
# 22                                         Four Stars
# 23                          Finally I am organized!!!
# 24                                         Five Stars
# 25                               Great HDMI converter
# 26                        Excellent sound. Good price
# 27                                         Five Stars
# 28                                           Love it!
# 29  ... the battery back up and also the battery f...
# ..                                                ...
# 70                                        Three Stars
# 71              Great product for a crazy cheap price
# 72                                  good sound but...
# 73  Easy to use for those less technically incline...
# 74                     Great Sound! Very comfortable.
# 75              NÃO ESTOU SATISFEITO COM ESSE PRODUTO
# 76  but some members on head-fi gave them really g...
# 77                                         Five Stars
# 78                                       dissapointed
# 79  ... with this in my bathroom - sounds so much ...
# 80                                         Five Stars
# 81                                         Five Stars
# 82                                         Four Stars
# 83                      Loud for such a small speaker
# 84  Clarity and comfort that keeps things interesting
# 85  Nice sound for what it is – a small Bluetooth ...
# 86                                           Love it!
# 87                                         Five Stars
# 88                                         Five Stars
# 89                                           One Star
# 90                 Worked for about a week then broke
# 91                                 This system rocks!
# 92      Really cool design and it goes up really easy
# 93           Loved it. So I gave the first one to ...
# 94                                         Four Stars
# 95                          Worked well the Caribbean
# 96                                         Five Stars
# 97                                         Five Stars
# 98                                            Painful
# 99                                      Solid Product
#
#                                           review_body review_date
# 0                                       As described.  2015-08-31
# 1                            It works as advertising.  2015-08-31
# 2                                         Works pissa  2015-08-31
# 3                                Did not work at all.  2015-08-31
# 4   Works well. Bass is somewhat lacking but is pr...  2015-08-31
# 5   The quality on these speakers is insanely good...  2015-08-31
# 6   Wish I could give this product more than five ...  2015-08-31
# 7                                         works great  2015-08-31
# 8   Great sound and compact. Battery life seems go...  2015-08-31
# 9                                    It works well~~~  2015-08-31
# 10                                          Alll good  2015-08-31
# 11    Love clock radio & CD player.  Easy to operate.  2015-08-31
# 12  Breaks very easily, and takes a while to load ...  2015-08-31
# 13  Excellent gain in radio frequency reception ov...  2015-08-31
# 14            everything I expected for a great price  2015-08-31
# 15  Love this small speaker with loud volume, grea...  2015-08-31
# 16  works as advertised.... nothing else to really...  2015-08-31
# 17  very good especially for notebooks with micro ...  2015-08-31
# 18  It does not copy CD-R s to USB as advertised. ...  2015-08-31
# 19    Did not last long,  Stop working within a year.  2015-08-31
# 20  Can't get any simpler that this.  And it works...  2015-08-31
# 21  Wish I could tilt it more up & down, but it wo...  2015-08-31
# 22          Good product, but took a week to receive.  2015-08-31
# 23  Makes a difference right out of the box. I hav...  2015-08-31
# 24                      great product, great service.  2015-08-31
# 25  Great little device if you need to convert mic...  2015-08-31
# 26  Excellent sound. Good price. Ear pads are less...  2015-08-31
# 27  Great Energy Level VI travel charger! Very com...  2015-08-31
# 28  Great space saving solution for consolidating ...  2015-08-31
# 29  This is less expensive than replacing the batt...  2015-08-31
# ..                                                ...         ...
# 70                                      More or less.  2015-08-31
# 71  These are like HDMI on steroids.  Very well co...  2015-08-31
# 72  well, it is a pain to have a odd charging cabl...  2015-08-31
# 73  So, I wouldn't have purchased this if it were ...  2015-08-31
# 74  Awesome earphones! The sound is great and the ...  2015-08-31
# 75  Day 20 November 2014 acquired the JBL portable...  2015-08-31
# 76  I'm really not qualified to review headphones,...  2015-08-31
# 77  Watched a video on how to install it on YouTub...  2015-08-31
# 78  I was very dissapointed with the quality of th...  2015-08-31
# 79  Replaced a Logitech wireless radio with this i...  2015-08-31
# 80  Exactly as described. The sleeves have helped ...  2015-08-31
# 81                                Good for the price.  2015-08-31
# 82                                          They work  2015-08-31
# 83  [[VIDEOID:46129030a61a028dbd8e69c13b30606]] Pl...  2015-08-31
# 84  [[VIDEOID:ca7421903fd1ad5c64ae1dc42a160649]] E...  2015-08-31
# 85  Nice sound for what it is – a small Bluetooth ...  2015-08-31
# 86      Battery is much improved from earlier models.  2015-08-31
# 87                                        Excellent!!  2015-08-31
# 88                               Hold TV very secure.  2015-08-31
# 89     now they tell me you can't split optical audio  2015-08-31
# 90  Sorry, this cable worked for about a week then...  2015-08-31
# 91  The sound quality is unbeatable.  I can't hand...  2015-08-31
# 92  Really cool design and it goes up really easy....  2015-08-31
# 93  I ordered one, Loved it.  So I  gave the first...  2015-08-31
# 94                                       Works great!  2015-08-31
# 95  I purchased the OUS00-0563 Super Thin Indoor H...  2015-08-31
# 96      The only batteries I buy for my DSLR Cameras.  2015-08-31
# 97                                           Loved it  2015-08-31
# 98  I was unable to use them because they hurt my ...  2015-08-31
# 99  Product arrived in good packaging and worked w...  2015-08-31
#
# [100 rows x 15 columns]

# %%
def get_aspects(x):
    doc=nlp(x) 
    doc=[i.text for i in doc if i.text not in stop_words and i.pos_=="NOUN"] ## Remove common words and retain only nouns
    doc=list(map(lambda i: i.lower(),doc)) ## Normalize text to lower case
    doc=pd.Series(doc)
    doc=doc.value_counts().head().index.tolist() ## Get 5 most frequent nouns
    return doc

aspects = []

for review in review_body :
    aspects.append(get_aspects(review))

# %%
dummy = "The sound quality of the speakers are wonderful. However, the packaging could have been better. Photos under low lighting is poor - both front and back cameras"
doc=nlp(dummy) 
for token in doc:
    print(token.text,token.tag_, token.dep_, token.pos_)
# Out:
# The DT det DET
# sound JJ amod ADJ
# quality NN nsubj NOUN
# of IN prep ADP
# the DT det DET
# speakers NNS pobj NOUN
# are VBP ROOT VERB
# wonderful JJ acomp ADJ
# . . punct PUNCT
# However RB advmod ADV
# , , punct PUNCT
# the DT det DET
# packaging NN nsubj NOUN
# could MD aux VERB
# have VB aux VERB
# been VBN ROOT VERB
# better JJR acomp ADJ
# . . punct PUNCT
# Photos NNS nsubj NOUN
# under IN prep ADP
# low JJ amod ADJ
# lighting NN pobj NOUN
# is VBZ ROOT VERB
# poor JJ amod ADJ
# - : punct PUNCT
# both DT preconj DET
# front NN amod NOUN
# and CC cc CCONJ
# back NN conj NOUN
# cameras NNS attr NOUN

# %%
#noun chunks

for chunk in doc.noun_chunks:
    print(chunk.text," ***", chunk.root.text, " ***",chunk.root.dep_," ***", chunk.root.head.text)
# Out:
# The sound quality  *** quality  *** nsubj  *** are
# the speakers  *** speakers  *** pobj  *** of
# the packaging  *** packaging  *** nsubj  *** been
# Photos  *** Photos  *** nsubj  *** is
# low lighting  *** lighting  *** pobj  *** under
# poor - both front and back cameras  *** cameras  *** attr  *** is

# %%
for token in doc:
    print(token.text,"****" ,token.dep_, "****" ,token.head.text, "****" ,token.is_stop,token.head.pos_,
          [child for child in token.children])
# Out:
# The **** det **** quality **** False NOUN []
# sound **** amod **** quality **** False NOUN []
# quality **** nsubj **** are **** False VERB [The, sound, of]
# of **** prep **** quality **** False NOUN [speakers]
# the **** det **** speakers **** False NOUN []
# speakers **** pobj **** of **** False ADP [the]
# are **** ROOT **** are **** False VERB [quality, wonderful, .]
# wonderful **** acomp **** are **** False VERB []
# . **** punct **** are **** False VERB []
# However **** advmod **** been **** False VERB []
# , **** punct **** been **** False VERB []
# the **** det **** packaging **** False NOUN []
# packaging **** nsubj **** been **** False VERB [the]
# could **** aux **** been **** False VERB []
# have **** aux **** been **** False VERB []
# been **** ROOT **** been **** False VERB [However, ,, packaging, could, have, better, .]
# better **** acomp **** been **** False VERB []
# . **** punct **** been **** False VERB []
# Photos **** nsubj **** is **** False VERB [under]
# under **** prep **** Photos **** False NOUN [lighting]
# low **** amod **** lighting **** False NOUN []
# lighting **** pobj **** under **** False ADP [low]
# is **** ROOT **** is **** False VERB [Photos, cameras]
# poor **** amod **** front **** False NOUN [-]
# - **** punct **** poor **** False ADJ []
# both **** preconj **** front **** False NOUN []
# front **** amod **** cameras **** False NOUN [poor, both, and, back]
# and **** cc **** front **** False NOUN []
# back **** conj **** front **** False NOUN []
# cameras **** attr **** is **** False VERB [front]

# %%
# Run this if you want to visualise dependancy tree
spacy.displacy.serve(doc, style='dep')
# Out:
#     Serving on port 5000...
#     Using the 'dep' visualizer
# 127.0.0.1 - - [11/Nov/2018 19:18:46] "GET / HTTP/1.1" 200 18731
# 127.0.0.1 - - [11/Nov/2018 19:18:47] "GET / HTTP/1.1" 200 18731
#     Shutting down server on port 5000.

# %%
## Zero RULE 
## Noun - Adjective pairs

## Very basic rule. Should be least weightage

noun_adj_pairs = []
for i,token in enumerate(doc):
    if token.pos_ not in ('NOUN','PROPN'):
        continue
    for j in range(i+1,len(doc)):
        if doc[j].pos_ == 'ADJ':
            noun_adj_pairs.append((token,doc[j]))
            break
noun_adj_pairs
# Out:
# [(Bass, lacking)]

# %%
## FIRST RULE OF DEPENDANCY PARSE -
## M - Sentiment modifier || A - Aspect

## RULE = M is child of A with a relationshio of amod

rule1_pairs = []
for token in doc:
    if token.dep_ == "amod":
        rule1_pairs.append((token.head.text, token.text))

rule1_pairs
# Out:
# [('quality', 'sound'),
#  ('lighting', 'low'),
#  ('front', 'poor'),
#  ('cameras', 'front')]

# %%
## SECOND RULE OF DEPENDANCY PARSE -
## M - Sentiment modifier || A - Aspect

#Direct Object - A is a child of something with relationship of nsubj, while 
# M is a child of the same something with relationship of dobj

#Assumption - A verb will have only one NSUBJ and DOBJ

rule2_pairs = []
for token in doc:
    children = token.children
    A = "999999"
    M = "999999"
    for child in children :
        if(child.dep_ == "nsubj"):
            A = child.text
        if(child.dep_ == "dobj"):
            M = child.text
    if(A != "999999" and M != "999999"):
        rule2_pairs.append((A, M))   
    
         
            
        
        
rule2_pairs        
        
        
   # if token.dep_ == "amod":
   #     rule1_pairs.append((token.head.text, token.text))
# Out:
# []

# %%
## THIRD RULE OF DEPENDANCY PARSE -
## M - Sentiment modifier || A - Aspect

#Adjectival Complement - A is a child of something with relationship of nsubj, while 
# M is a child of the same something with relationship of acomp

#Assumption - A verb will have only one NSUBJ and DOBJ

rule3_pairs = []
for token in doc:

    children = token.children
    A = "999999"
    B = "999999"
    for child in children :
        if(child.dep_ == "nsubj"):
            A = child.text
          
        if(child.dep_ == "acomp"):
            M = child.text
        
    if(A != "999999" and M != "999999"):
        rule3_pairs.append((A, M)) 


            
        
        
rule3_pairs        
        
        
   # if token.dep_ == "amod":
   #     rule1_pairs.append((token.head.text, token.text))
# Out:
# [('quality', 'wonderful'), ('packaging', 'better'), ('Photos', 'better')]

# %%
## FOURTH RULE OF DEPENDANCY PARSE -
## M - Sentiment modifier || A - Aspect

#Adverbial modifier to a passive verb - A is a child of something with relationship of nsubjpass, while 
# M is a child of the same something with relationship of advmod

#Assumption - A verb will have only one NSUBJ and DOBJ

rule4_pairs = []
for token in doc:

    children = token.children
    A = "999999"
    M = "999999"
    for child in children :
        if(child.dep_ == "nsubjpass"):
            A = child.text
          
        if(child.dep_ == "advmod"):
            M = child.text
        
    if(A != "999999" and M != "999999"):
        rule4_pairs.append((A, M)) 


            
        
        
rule4_pairs        
        
        
   # if token.dep_ == "amod":
   #     rule1_pairs.append((token.head.text, token.text))
# Out:
# []

# %%
## FIFTH RULE OF DEPENDANCY PARSE -
## M - Sentiment modifier || A - Aspect

#Complement of a copular verb - A is a child of M with relationship of nsubj, while 
# M has a child with relationship of cop

#Assumption - A verb will have only one NSUBJ and DOBJ

rule5_pairs = []
for token in doc:
    children = token.children
    A = "999999"
    buf_var = "999999"
    for child in children :
        if(child.dep_ == "nsubj"):
            A = child.text
          
        if(child.dep_ == "cop"):
            buf_var = child.text
        
    if(A != "999999" or buf_var != "999999"):
        rule3_pairs.append((A, token.text)) 


            
        
        
rule5_pairs        
        
        
   # if token.dep_ == "amod":
   #     rule1_pairs.append((token.head.text, token.text))
# Out:
# []

# %%
rule3_pairs
# Out:
# [('quality', 'wonderful'), ('packaging', 'better'), ('Photos', 'better')]

# %%
aspects = []
aspects = rule1_pairs + rule2_pairs + rule3_pairs + rule4_pairs + rule5_pairs 
aspects

review_id = "guhjsus23"

{"review_id" : review_id, "aspects" : aspects }
aspects = []

# %%
def apply_extraction(row,nlp):
    review_body = row['review_body']
    review_id = row['review_id']

    doc=nlp(review_body)


    ## FIRST RULE OF DEPENDANCY PARSE -
    ## M - Sentiment modifier || A - Aspect
    ## RULE = M is child of A with a relationshio of amod
    rule1_pairs = []
    for token in doc:
        if token.dep_ == "amod":
            rule1_pairs.append((token.head.text, token.text))
            #return row['height'] * row['width']


    ## SECOND RULE OF DEPENDANCY PARSE -
    ## M - Sentiment modifier || A - Aspect
    #Direct Object - A is a child of something with relationship of nsubj, while
    # M is a child of the same something with relationship of dobj
    #Assumption - A verb will have only one NSUBJ and DOBJ

    rule2_pairs = []
    for token in doc:
        children = token.children
        A = "999999"
        M = "999999"
        for child in children :
            if(child.dep_ == "nsubj"):
                A = child.text
            if(child.dep_ == "dobj"):
                M = child.text
        if(A != "999999" and M != "999999"):
            rule2_pairs.append((A, M))


    ## THIRD RULE OF DEPENDANCY PARSE -
    ## M - Sentiment modifier || A - Aspect
    #Adjectival Complement - A is a child of something with relationship of nsubj, while
    # M is a child of the same something with relationship of acomp
    #Assumption - A verb will have only one NSUBJ and DOBJ

    rule3_pairs = []

    for token in doc:

        children = token.children
        A = "999999"
        M = "999999"
        for child in children :
            if(child.dep_ == "nsubj"):
                A = child.text

            if(child.dep_ == "acomp"):
                M = child.text

        if(A != "999999" and M != "999999"):
            rule3_pairs.append((A, M))

    ## FOURTH RULE OF DEPENDANCY PARSE -
    ## M - Sentiment modifier || A - Aspect

    #Adverbial modifier to a passive verb - A is a child of something with relationship of nsubjpass, while
    # M is a child of the same something with relationship of advmod

    #Assumption - A verb will have only one NSUBJ and DOBJ

    rule4_pairs = []
    for token in doc:


        children = token.children
        A = "999999"
        M = "999999"
        for child in children :
            if(child.dep_ == "nsubjpass"):
                A = child.text

            if(child.dep_ == "advmod"):
                M = child.text

        if(A != "999999" and M != "999999"):
            rule4_pairs.append((A, M))


    ## FIFTH RULE OF DEPENDANCY PARSE -
    ## M - Sentiment modifier || A - Aspect

    #Complement of a copular verb - A is a child of M with relationship of nsubj, while
    # M has a child with relationship of cop

    #Assumption - A verb will have only one NSUBJ and DOBJ

    rule5_pairs = []
    for token in doc:
        children = token.children
        A = "999999"
        buf_var = "999999"
        for child in children :
            if(child.dep_ == "nsubj"):
                A = child.text

            if(child.dep_ == "cop"):
                buf_var = child.text

        if(A != "999999" and buf_var != "999999"):
            rule3_pairs.append((A, token.text))

    aspects = []
    aspects = rule1_pairs + rule2_pairs + rule3_pairs +rule4_pairs +rule5_pairs
    dic = {"review_id" : review_id , "aspect_pairs" : aspects}
    return dic

# %%
nlp=spacy.load("en_core_web_lg")
reviews.apply(lambda row: apply_extraction(row,nlp), axis=1)[4]
# Out:
# {'review_id': 'R372S58V6D11AT', 'aspect_pairs': [('Bass', 'lacking')]}

# %%
list(reviews.loc[reviews['review_id'] == "R2S8TX3KZU9TNW"]['review_body'])
# Out:
# ['[[VIDEOID:ca7421903fd1ad5c64ae1dc42a160649]] Earbuds have always been an issue for me. Mine is one of those stereotypical stories -- I can\'t find a pair that fits my ears well. I\'ve tried so many types of earbuds and most of them give my ear canals some sort of fatigue. It\'s not that they sound bad, just that keeping them in my ears for more than 10 minutes is painful. The only ones I could tolerate were the Apple EarPods, and I have a love/hate relationship with them. Sure, they sit nicely in my ears, but them being fully open means I lose my music to the crickets of night and pelicans of day. Well, no more! I found the Flare R2A in-ear monitors, and seems my fear of earbuds is over.<br /><br />Disclaimer: This product was provided at a discounted price in exchange for an honest review.<br /><br />The R2s began their life on Kickstarter with a campaign that raised over $170,000. That\'s quite a lot for IEMs, which are a rather niche market. Flare is a British company that strives for excellence in sound, and hopes that the world can join them in this pursuit. Before the R2s, the company made loudspeakers, so in-ears is a bit of a different industry. I think they did a fine job of things.<br /><br />I listen to a lot of different genres of music, but mostly folk and dream pop lately. To test out the R2s, I listened to hip-hop, jazz, EDM, instrumental guitar and piano, rock, classical, and of course the aforementioned folk. They performed consistently well in every genre. They also look great.<br /><br />First, of course, the sound. These IEMs aren\'t active noise canceling or anything fancy, which is good because noise canceling often diminishes the sound quality. The R2s are still great for keeping outside noises to a minimum. They use the same plushy foam tips as earplugs, which makes for a comfortable and quiet listening environment. I tried them at work, in the bus, walking down a busy road, and even in a studio while recording. There\'s absolutely no sound leakage at all, which is great for quiet environments, and none of the quality seems to be lost when the environment is noisy.<br /><br />People sometimes rant about flat response and how it\'s better than everything else. Those people might be troubled by the R2s. They\'re warmer than most earbuds, but don\'t have muddy bass. The main issue with earbuds is always treble: there\'s way too much of it everywhere. Then Skullcandy wanted to have fun so they started adding a bunch of bass to the mix. Everything above 80Hz seemed to have been lost. The R2s have none of those problems -- highs are crisp, mids cut through well, and the lows of course deliver the much-needed punch, rather than a drone. The responsiveness of everything is very tight.<br /><br />As I said before, everything I listened to with these IEMs sounded wonderful. They revealed details in songs that I didn\'t know were there, while also being comfortable, affordable, and easy to use. The highs were not overbearing, but pronounced; the high-mids don\'t clutter the highs at all; the low-mids keep all the bass lines in check; and the lows make sure you remember that the bass drum exists without making you forget about the guitars in the mid-range. That\'s a great achievement. I really love the way these sound. Everything is balanced. Overall, it\'s a bit warm, but I would much rather it be warm than sound like tinny old Apple earbuds from the early 2000s, with their mesh and bass-less muddle.<br /><br />On to the design. These things are beautifully minimal, but aren\'t trying to be artistic, which is nice for a change. The earbuds themselves are black (or whatever color you chose), and the tips and cable match that. There\'s also a rectangular machined aluminum box that splits the stereo signal for the left and right channels. It doesn\'t need to be as big as it is, but it does add some pizzazz to things. Lastly, there\'s the 3.5mm connector, which on mine is black with two gold stripes running through  ...
