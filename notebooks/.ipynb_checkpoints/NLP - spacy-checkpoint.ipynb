# %%
import spacy
import pandas as pd
import os
import sys

# %%
#Get this from some place else. This is just for dummy usage
stop_words=["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", 
            "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", 
            "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", 
            "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", 
            "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", 
            "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", 
            "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", 
            "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", 
            "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than",
            "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]


nlp=spacy.load("en_core_web_lg")

# %%
BASE_PATH = os.path.abspath(os.path.join('..')) # base path of project

file_path = BASE_PATH + '/data/raw/amazon_reviews_us_Electronics_v1_00.tsv'

raw_data = pd.read_table(file_path,error_bad_lines=False, nrows=100)

review_body = raw_data['review_body']

# %%
def get_aspects(x):
    doc=nlp(x) 
    doc=[i.text for i in doc if i.text not in stop_words and i.pos_=="NOUN"] ## Remove common words and retain only nouns
    doc=list(map(lambda i: i.lower(),doc)) ## Normalize text to lower case
    doc=pd.Series(doc)
    doc=doc.value_counts().head().index.tolist() ## Get 5 most frequent nouns
    return doc

aspects = []

for review in review_body :
    aspects.append(get_aspects(review))
    
aspects
# Out:
# [[],
#  ['advertising'],
#  ['pissa', 'works'],
#  [],
#  ['bass', 'item'],
#  ['quality', 'speakers', 'bass'],
#  ['stars', 'product', 'lifesaver'],
#  [],
#  ['battery', 'product', 'life', 'sound'],
#  ['well~~~'],
#  [],
#  ['clock', 'love', 'player', 'cd', 'radio'],
#  ['breaks', 'music'],
#  ['radio', 'antenna', 'frequency', 'gain', 'stock'],
#  ['everything', 'price'],
#  ['beach', 'volume', 'speaker'],
#  ['nothing'],
#  ['hdmi', 'computer', 'notebooks', 'screen'],
#  ['cd', 'machine', 'usb', 'r', 'collection'],
#  ['year'],
#  ['lip', 'chair', 'side', 'arm', 'layer'],
#  ['price', 'product', 'one', 'tv'],
#  ['week', 'product'],
#  ['br', 'place', 'apple', 'bluetooth', 'purchase'],
#  ['service', 'product'],
#  ['mine', 'great.<br', 'size', 'computer', 'audio'],
#  ['br', 'money', 'headphones', 'sound', 'pads'],
#  ['travel', 'charger', 'order', 'charging', 'service'],
#  ['space', 'saving', 'solution', 'dvds'],
#  ['battery', 'fine'],
#  ['puts', 'sound'],
#  ['device', '4s', 'music', 'product', 'system'],
#  ['purchase'],
#  ['school', 'price', 'quality', 'year'],
#  ['bass', 'songs', 'headphones', 'ear', 'value'],
#  ['tv', 'usb', 'power', 'speakers', 'inputs'],
#  ['networks'],
#  ['colors', 'case', 'headphones'],
#  ['albums', 'item', 'birthday', 'days', 'chance'],
#  ['cable'],
#  ['price', 'speaker', 'shipping'],
#  ['noise', 'headphones', 'reduction', 'flight', 'phones'],
#  ['problem'],
#  ['product'],
#  ['sound', 'mounts', 'surround'],
#  ['color', 'course', 'fact', 'ears', 'sound'],
#  [],
#  ['price', 'quality'],
#  ['batteries', 'replacement', 'phones'],
#  [],
#  ['features', 'setup', 'video', 'customers', 'hacking'],
#  ['%', 'noise', 'cancellation', 'year', 'traveler'],
#  ['products', 'buy'],
#  ['form', 'room', 'family', 'weather', 'changes'],
#  ['tv'],
#  ['crystal', 'product', 'anyone', 'quality', 'clarity'],
#  ['headphones', 'music', 'hours', 'musi', 'service'],
#  ['weeks', 'sponginess', 'tips', 'headphones', 'gym'],
#  ['mount', 'monitor', 'people', 'mounts', 'way'],
#  ['job'],
#  ['instructions', 'player', 'button', 'error!&#34;.', 'middle'],
#  ['bike', 'time', 'jam', 'speakers', 'music'],
#  ['delivery', 'item'],
#  ['malfunction', 'side', 'purchase', 'o', 'times'],
#  ['v', 'figure', 'dc', 'policy', 'radio'],
#  ['complaints', 'product'],
#  ['features', 'sound', 'dock', 'port', 'usb'],
#  ['speaker', 'speakers', 'sound', 'product', 'range'],
#  ['channels', 'son'],
#  ['recipient', 'gift'],
#  [],
#  ['nothing', 'price', 'heartbeat', 'cables', 'steroids'],
#  ['phone', 'pain', 'instructions', 'cable'],
#  ['stations', 'preamp', 'antenna', 'quality', 'line'],
#  ['ear', 'motion', 'earphones', 'golf', 'pieces'],
#  ['noise', 'times', 'day', 'warranty', 'circuit'],
#  ['headphones', 'bass', 'members', 'head', "/>they're"],
#  ['video'],
#  ['phone', 'pocket', 'headphone', 'headphones', 'dollar'],
#  ['bathroom', 'wireless', 'sounds', 'radio'],
#  ['sleeves', 'work', 'space', 'thanks'],
#  ['price'],
#  [],
#  ['cup', 'button', 'hours', 'battery', 'suction'],
#  ['ears', 'earbuds', 'iems', 'sound', 'microphone'],
#  ['sound', 'bass', 'stations', 'price', '–'],
#  ['models', 'battery'],
#  [],
#  ['tv'],
#  ['audio'],
#  ['fault', 'cable', 'exception', 'expensives', 'ones'],
#  ['room', 'size', 'volume', 'system', 'quality'],
#  ['adjustment', 'inch', 'amount', 'tv', 'design'],
#  ['problem', 'husband', 'one', 'month'],
#  [],
#  ['difference', 'reception', 'wall', 'tv', 'tape'],
#  ['batteries'],
#  [],
#  ['ears', 'min'],
#  ['product', 'packaging']]
